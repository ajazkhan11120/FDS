# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots()

x=[2,4,5,8,6,9,5,8,2,3,6,5,2,2,6,9,5,6,6,5,5,6,5,2,3,5,5]
y=[3,8,6,7,5,6,9,5,2,4,2,5,1,2,6,5,2,3,5,2,3,6,5,3,9,5,6]

ax.scatter(x,y)

# %%
import pandas as pd

iris=pd.read_csv("C:/FDS/Iris.csv")

print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots()

ax.scatter(iris['SepalLengthCm'],iris['SepalWidthCm'])

ax.set_title('Iris Dataset')

ax.set_xlabel('sepal_len')

ax.set_ylabel('sepal_wid')
# Out:
# Text(0, 0.5, 'sepal_wid')

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

x=range(1,6)

y=np.random.randint(1,20,5)

plt.plot(x,y)

plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x1deb897b970>,
#   <matplotlib.axis.YTick at 0x1deb897b550>,
#   <matplotlib.axis.YTick at 0x1deb89f14c0>,
#   <matplotlib.axis.YTick at 0x1deb8a1cbb0>,
#   <matplotlib.axis.YTick at 0x1deb8a24100>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

x=[2,4,5,8,6,9,5,8,2,3,6,5,2,2,6,9,5,6,6,5,5,6,5,2,3,5,5]
y=[3,8,6,7,5,6,9,5,2,4,2,5,1,2,6,5,2,3,5,2,3,6,5,3,9,5,6]


plt.plot(x,y)

plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x1deb8a4a220>,
#   <matplotlib.axis.YTick at 0x1deb8a46e20>,
#   <matplotlib.axis.YTick at 0x1deb8a43c70>,
#   <matplotlib.axis.YTick at 0x1deb8a96ca0>,
#   <matplotlib.axis.YTick at 0x1deb8a90310>,
#   <matplotlib.axis.YTick at 0x1deb8a7c8e0>,
#   <matplotlib.axis.YTick at 0x1deb8a96460>,
#   <matplotlib.axis.YTick at 0x1deb8a9b1f0>,
#   <matplotlib.axis.YTick at 0x1deb8a9b700>,
#   <matplotlib.axis.YTick at 0x1deb8a9bc10>,
#   <matplotlib.axis.YTick at 0x1deb8aa3190>,
#   <matplotlib.axis.YTick at 0x1deb8aa36a0>,
#   <matplotlib.axis.YTick at 0x1deb8aa3bb0>,
#   <matplotlib.axis.YTick at 0x1deb8a9b790>,
#   <matplotlib.axis.YTick at 0x1deb8a833d0>,
#   <matplotlib.axis.YTick at 0x1deb8aa38b0>,
#   <matplotlib.axis.YTick at 0x1deb8aab190>,
#   <matplotlib.axis.YTick at 0x1deb8aab6a0>,
#   <matplotlib.axis.YTick at 0x1deb8aabbb0>,
#   <matplotlib.axis.YTick at 0x1deb8ab1100>,
#   <matplotlib.axis.YTick at 0x1deb8ab1610>,
#   <matplotlib.axis.YTick at 0x1deb8ab1b20>,
#   <matplotlib.axis.YTick at 0x1deb8ab5070>,
#   <matplotlib.axis.YTick at 0x1deb8ab1190>,
#   <matplotlib.axis.YTick at 0x1deb8aab220>,
#   <matplotlib.axis.YTick at 0x1deb8a9b3d0>,
#   <matplotlib.axis.YTick at 0x1deb8ab5580>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import pandas as pd
df=pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisc','']
    'age':[23,78,25,63,52,65,23],
    'gender':['M','F','M',"M","M",'M','F'],
    'state':['abc','p','']
    'num_child':
    
})

# %%
import pandas as pd

iris=pd.read_csv("C:/FDS/Iris.csv", index_col=0)

print(iris.head())
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
col=iris.columns.drop(['Species'])

x_data=range(0,iris.shape[0])

fig,ax=plt.subplots()

for column in col:
    ax.plot(x_data,iris[column],label=column)
    
ax.set_title('iris dataset')
ax.legend()

# %%
fig ,ax=plt.subplots()

ax.hist(iris['SepalLengthCm'])

ax.set_title('irir')

ax.set_xlabel('Sepal_len')

ax.set_ylabel('frq')
# Out:
# Text(0, 0.5, 'frq')

# %%
wine_reviews=pd.read_csv("C:/FDS/winemag-data-130k-v2.csv", index_col=0)
print(wine_reviews.head())
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
fig,ax=plt.subplots()

data=wine_reviews['points'].value_counts()

points=data.index
frequency=data.values

ax.bar(points,frequency)

ax.set_title('wine Revwiew')
ax.set_xlabel('point')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
wine_reviews['points'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
wine_reviews.groupby('country').price.mean().sort_values(ascending=False)[:6].plot.bar()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
import pandas as pd
df=pd.DataFrame({
    'Name':['jhon','mary','peter','bill','lice'],
    'age':[74,55,22,30,15],
    'gender':['M','F','M','M','F'],
    'state':['cailefoornia','dc','cailefoornia','texas','cailefoornia'],
    'number_child':[2,1,0,3,1]
})

df.groupby(['state','gender']).size().unstack().plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='state'>

# %%
import pandas as pd

from matplotlib import pyplot as plt

data={
    'country':['usa','canada','uuk','france'],
    'gdp':[45000,65000,62000,52000],
    'income':[4000,5000,3000,6000]
}

df=pd.DataFrame(data)

df.plot(x='country',y=['gdp','income'],kind='bar')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
import numpy as np

import matplotlib.pyplot as plt

plt.figure(figsize[15,10])



plt.bar(x,totaldeath,color='black',width=0.25)
plt.bar(x+0.25,totalrec,color='g',width=0.25)
plt.bar(x+0.25,activecase,color='b',width=0.25)




plt.lengend1(['Total Death','Total Recovery','Active Cases'])



plt.xticks

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt

Data={
    'task':[300,500,700],
    'task type':['pending','ongoing','completrd']
}

df=DataFrame(Data)

df.set_index('task type',inplace=True)


df.plot.pie(y='task',figsize=(5,5),autopct='%1.1f%%',startangle=90)
# Out:
# <AxesSubplot:ylabel='task'>

# %%
import matplotlib.pyplot as plt
# %matplotlob inline

labels=['civil','electical',]al

# %%
import numpy as np
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("2,2,1")
plt.subplot(2,2,2)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title("2,2,2")
plt.subplot(2,2,3)
plt.scatter(range(1,6),np.random.randint(1,20,5),s=100,color="r")
plt.title("2,2,3")
plt.subplot(2,2,4)
plt.plot(range(1,6),np.random.randint(1,20,5), marker='o',color='g',linestyle='--')
plt.title("2,2,4")
# Out:
# Text(0.5, 1.0, '2,2,4')

# %%
plt.bar(range(1,6), np.random.randint(1,20,5),width=0.5)
plt.scatter(range(1,6),np.random.randint(1,20,5),s=100,color="r")
plt.plot(range(1,6),np.random.randint(1,20,5), marker='o',color='g',linestyle='--')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

os.chdir('C:/FDS')

cars_data=pd.read_csv('Toyota.csv',index_col=0,na_values=["??","???"])
cars_data.size
# Out:
# 14360

# %%
cars_data=pd.read_csv('Toyota.csv',index_col=0)
cars_data.head()
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90       1.0          0  2000  three    1165
# 1  13750  23.0  72937   Diesel  90       1.0          0  2000      3    1165
# 2  13950  24.0  41711   Diesel  90       NaN          0  2000      3    1165
# 3  14950  26.0  48000   Diesel  90       0.0          0  2000      3    1165
# 4  13750  30.0  38500   Diesel  90       0.0          0  2000      3    1170

# %%
sns.set(style="darkgrid")
sns.regplot(x=cars_data['Age'],y=cars_data['Price'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.regplot(x=cars_data['Age'],y=cars_data['Price'],marker="*",fit_reg=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Price'>

# %%
sns.lmplot(x='Age',y='Price',data=cars_data,fit_reg=False,hue='FuelType',legend=True,palette="Set1")

# %%
sns.distplot(cars_data['Age'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(cars_data['Age'],kde=False,bins=5)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age'>

# %%
sns.countplot(x="FuelType",data=cars_data)
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
sns.countplot(x="FuelType",data=cars_data ,hue="Automatic")
# Out:
# <AxesSubplot:xlabel='FuelType', ylabel='count'>

# %%
pd.crosstab(index=cars_data["Automatic"],columns=cars_data['FuelType'],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73
